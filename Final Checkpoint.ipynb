# %% [markdown]
# # Final Project Checkpoint
# ### Homelessness in America

# %% [markdown]
# There is a large homeless population in California, and it is one that I have seen first hand my entire life which is why I chose to take a look at the data behind it. It is actually hard to avoid seeing this problem anywhere you go. Instead of looking just at California's data, I wanted to look at the data from all states in America to see what is really happening in the country as well as what the states are doing in order to help out this population. With this project I am hoping to just give people a better idea of the homeless problem in America whether they are uninformed or minimally informed. I would like to show the numbers and analysis behind blind beliefs about homelessness as a whole in America.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# I will need numpy in order to do math with the numbers providing like summing columns. I will use pandas for at least reading the csv but also some functions will be used from the library and maybe some graphs. I will use both seaborn and matplotlib for graphing data and visualizations but also figuring out what variables are correlated and significant from the data.

# %% [markdown]
# The data I got is from the hudexchange website (https://www.hudexchange.info/resource/3031/pit-and-hic-data-since-2007/). I believe its purpose was to be used like I am using it in order to demonstrate the homelessness problem in America and it was collected from 2007 and updated every year until 2023. I ran a correlation test and it looks like the data that is by states only has one numeric variable, so I have to change all of the string with numbers into integers but the dataset by CoC seems to be working fine. In the data by state, there are 59 rows and 643 columns, and for the data by CoC, there are 389 rows and 645 columns.

# %%
State = pd.read_csv('2007-2023-PIT-Counts-by-State.csv')
CoC = pd.read_csv('2007-2023-PIT-Counts-by-CoC.csv')

# %%
State.shape
# Out:
# (59, 643)

# %%
CoC.shape
# Out:
# (389, 645)

# %%
sns.heatmap(State.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,15))
sns.heatmap(CoC.corr(numeric_only=True))
# Out:
# <Axes: >
