# %% [markdown]
# # More plotting with Matplotlib
# If you want to type along with me, use [this notebook](https://humboldt.cloudbank.2i2c.cloud/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fbethanyj0%2Fdata271_sp24&branch=main&urlpath=tree%2Fdata271_sp24%2Fdemos%2Fdata271_demo16_live.ipynb) instead.
# If you don't want to type and want to follow along just by executing the cells, stay in this notebook.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data in a Pandas DataFrame

# %%
# Make peppers dataframe
df = pd.DataFrame({
    'Scoville_scale':[0.0,5000.0,10000.0,60000.0,500000.0,2000000.0],
    'Chili_pepper_scale':[0,1,2,3,4,5],
    'Name': ['Bell pepper','Espelette pepper','Serrano pepper',"Bird's eye chili",'Chocolate habanero','Carolina Reaper'],
    'Feeling':['Not even spicy','Uncomfortable','I regret this','4th stage of grief','Practically ate pepper spray','Actually ate pepper spray']
    
})
df
# Out:
#    Scoville_scale  Chili_pepper_scale                Name  \
# 0             0.0                   0         Bell pepper
# 1          5000.0                   1    Espelette pepper
# 2         10000.0                   2      Serrano pepper
# 3         60000.0                   3    Bird's eye chili
# 4        500000.0                   4  Chocolate habanero
# 5       2000000.0                   5     Carolina Reaper
#
#                         Feeling
# 0                Not even spicy
# 1                 Uncomfortable
# 2                 I regret this
# 3            4th stage of grief
# 4  Practically ate pepper spray
# 5     Actually ate pepper spray

# %%
# plotting with matplotlib
plt.plot(df.Scoville_scale,df.Chili_pepper_scale,'ro')
plt.show()

# %%
# another way plt.plot(x_label,y_label,[format],data = Pandas DataFrame)
plt.plot('Scoville_scale','Chili_pepper_scale','ro',data = df)
plt.show()

# %%
df.Chili_pepper_scale.iloc[-1]
# Out:
# 5

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot('Scoville_scale','Chili_pepper_scale','go-',data = df)
ax.set_xlabel('Schoville scale')
ax.set_ylabel('Chili pepper scale')
ax.set_title('Spicy scales')
ax.annotate('mild',xytext=(100015,0.15),xy = (0,0), arrowprops = dict(arrowstyle='->'))
ax.annotate('spicy',xytext=(1800000,4.5),
            xy = (df.Scoville_scale.iloc[-1],df.Chili_pepper_scale.iloc[-1]), 
            arrowprops = dict(arrowstyle='->'))
plt.show()

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/bethanyj0/data271_sp24/main/midterms/property_price.csv')
df2.head()
# Out:
#    Rank               City  Price To Income Ratio  \
# 0     1  Santa Barbara, CA                   13.3
# 1     2       Brooklyn, NY                   11.2
# 2     3         Queens, NY                   11.1
# 3     4       New York, NY                   10.4
# 4     5        Oakland, CA                    9.4
#
#    Gross Rental Yeild City Centre  Gross Rental Yeild Outside of City   \
# 0                             4.4                                  6.2
# 1                             4.7                                  4.3
# 2                             2.8                                  5.3
# 3                             5.6                                  5.4
# 4                             6.6                                  5.4
#
#    Price To Rent Ratio City Centre  Price To Rent Ratio Outside of City  \
# 0                             23.0                                 16.3
# 1                             21.5                                 23.0
# 2                             35.6                                 18.8
# 3                             17.7                                 18.7
# 4                             15.2                                 18.5
#
#    Mortgage as a Percentage of Income  Affordability Index
# 0                               103.7                  1.0
# 1                                89.9                  1.1
# 2                                91.3                  1.1
# 3                                85.9                  1.2
# 4                                77.5                  1.3

# %%
cali = df2[df2['City'].str.contains('CA')]
florida = df2[df2['City'].str.contains('FL')]

# %%
df2['state'] = [i[-2:] for i in df2['City']]

# %%
df2
# Out:
#     Rank               City  Price To Income Ratio  \
# 0      1  Santa Barbara, CA                   13.3
# 1      2       Brooklyn, NY                   11.2
# 2      3         Queens, NY                   11.1
# 3      4       New York, NY                   10.4
# 4      5        Oakland, CA                    9.4
# ..   ...                ...                    ...
# 89    90        Detroit, MI                    1.4
# 90    91        Memphis, TN                    1.3
# 91    92          Tulsa, OK                    1.3
# 92    93        El Paso, TX                    1.2
# 93    94      Baltimore, MD                    1.0
#
#     Gross Rental Yeild City Centre  Gross Rental Yeild Outside of City   \
# 0                              4.4                                  6.2
# 1                              4.7                                  4.3
# 2                              2.8                                  5.3
# 3                              5.6                                  5.4
# 4                              6.6                                  5.4
# ..                             ...                                  ...
# 89                            21.7                                 14.3
# 90                            38.7                                 10.4
# 91                            15.8                                 16.2
# 92                            17.2                                 17.7
# 93                            31.2                                 30.8
#
#     Price To Rent Ratio City Centre  Price To Rent Ratio Outside of City  \
# 0                              23.0                                 16.3
# 1                              21.5                                 23.0
# 2                              35.6                                 18.8
# 3                              17.7                                 18.7
# 4                              15.2                                 18.5
# ..                              ...                                  ...
# 89                              4.6                                  7.0
# 90                              2.6                                  9.6
# 91                              6.3                                  6.2
# 92                              5.8                                  5.7
# 93                              3.2                                  3.3
#
#     Mortgage as a Percentage of Income  Affordability Index state
# 0                                103.7                  1.0    CA
# 1                                 89.9                  1.1    NY
# 2                                 91.3                  1.1    NY
# 3                                 85.9                  1.2    NY
# 4                                 77.5                  1.3    CA
# ..                                 ...                  ...   ...
# 89                                11.0                  9.1    MI
# 90                                11.0                  9.1    TN
# 91                                 9.9                 10.1    OK
# 92                                10.2                  9.8    TX
# 93                                 7.8                 12.8    MD
#
# [94 rows x 10 columns]

# %%
df2['state'].value_counts()
# Out:
# CA    15
# FL     8
# WA     7
# TX     7
# TN     4
# NY     4
# CO     3
# MI     3
# VA     3
# NC     3
# LA     2
# OK     2
# PA     2
# AL     2
# KY     2
# NV     2
# SC     2
# OR     2
# OH     2
# WI     2
# DC     1
# IL     1
# KS     1
# NE     1
# IN     1
# AZ     1
# AK     1
# GA     1
# NJ     1
# UT     1
# MO     1
# MN     1
# HI     1
# MA     1
# ID     1
# NM     1
# MD     1
# Name: state, dtype: int64

# %%
figure = plt.figure()
ax = figure.add_axes([0,0,1,1])
ax.plot('Affordability Index','Price To Income Ratio','o',data = cali)
ax.plot('Affordability Index','Price To Income Ratio','o',data=florida)
ax.legend(loc = 'upper right')
plt.show()
