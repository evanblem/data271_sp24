# %%
# Initialize Otter
import otter
grader = otter.Notebook("lab03.ipynb")

# %% [markdown]
# # Lab 3: Regular Expression with Python

# %% [markdown]
# Welcome to Lab 3 of DATA 271!
#
# This document contains examples and small tasks ("appetizers") for you to make sure you understand the examples.  The culminating task ("main course") at the end of the document is more complex, and uses most of the topics you have will have worked through. You should rarely remain stuck for more than a few minutes on questions in labs, so feel free to ask for help. Collaborating on labs is more than okay -- it's encouraged! Explaining things is beneficial -- the best way to solidify your knowledge of a subject is to explain it. Please don't just share answers, though.
#
# For this lab and all future ones, please be sure to not re-assign variables throughout the notebook! For example, if you use `my_list` in your answer to one question, do not reassign it later on. Otherwise, you will fail tests that you passed previously!

# %% [markdown]
# ### In today's lab, we will
# - Learn basic syntax for regular expression in Python and be able to write simple regular expressions using common operations in pattern matching.
# - Understand the flexibility regular expression affords in searching and articulate at least one real world example where this is useful
# - Become familiar with Python's `re` module and some of its functions such as `findall()`, `search()`, and `sub()`.
# - Become more familiar with using online resources such as documentation, "cheat sheets" and Stack Exchange to independently learn more about a technical topic.

# %% [markdown]
# ## Overview
#
# Regular expression (shortened as regex or regexp) can be used for pattern matching in a text editor.  For example, when you use the "find and replace" feature in Microsoft Word, you are asking the computer to find specific strings which match a pattern and replace them with another string. We might desire a more flexible way to search and replace. For example, we might wish to locate and replace a word spelled two different ways in a text: serialise and serialize (British and American spelling). The regular expression `seriali[sz]e` matches both "serialise" and "serialize". Wildcard characters also achieve this, but are more limited in what they can pattern.
#
# Other examples where this flexibilty is useful might be searching for and extracting email addresses from a file.  We know there will be an at sign (@), but don't know what the constraints are in front of it in terms of word length or characters used. It is possible to read through texts and look for patterns using string methods like `split()` and `find()`. However, searching and extracting is so common that there is a powerful library for these tasks (`re`).
#
# The `re` module provides a set of powerful regular expression facilities, which allows you to quickly check whether a given string matches a given pattern (using the match function), or contains such a pattern (using the search function). A regular expression is a string pattern written in a compact (and quite cryptic) syntax.
#
# The module functions fall into three categories:
# - pattern matching
# - substitution
# - splitting
#
# The regex describes a pattern to locate in the text, and then we can use specific methods to accomplish tasks.  You can then ask questions such as “Does this string match the pattern?”, or “Is there a match for the pattern anywhere in this string?” You can also use regular expression to modify a string or to split it apart in various ways.
#
# The documentation provides more details: https://docs.python.org/3/library/re.html.

# %% [markdown]
# ### Pattern matching

# %%
import re # Imports the re module

#Check if the string starts with "The" and ends with "Spain":

txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)

if x:
  print("YES! We have a match!")
else:
  print("No match")

# %%
#Check if the string starts with "The" and ends with "Spain":
txt = "The Running of the Bulls occurs in Pamplona, Spain"
x = re.search("^The.*Spain$", txt)

if x:
  print("YES! We have a match!")
else:
  print("No match")

# %%
#Check if the string starts with "The" and ends with "Spain":

txt = "The Louvre is in Paris, France"
x = re.search("^The.*Spain$", txt)

if x:
  print("YES! We have a match!")
else:
  print("No match")

# %% [markdown]
# ### Print Matches
# You can print any matches found with the following.

# %%
txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)
len(x) # how many matches are found

# %%
# returns an empty list if no matches are found
txt = "The rain in Spain"
x = re.findall("Portugal", txt)
print(x)

# %% [markdown]
# ### Search
# The `search()` function searches the string for a match and returns a match object if there is a match.  If there is more than one match, only the first occurence will be returned.  If there are no matches `None` is returned.  The match object returned has properties and methods which can provide more information about the search such as
# - `span()` which returns a tuple containing the start and end positions of the match
# - `group()` returns the part of the string where there was a match

# %%
txt = "The rain in Spain"
# search for first white space character \s
x = re.search("\s", txt)

print("The first white-space character is located in position:", x.start())

# %%
x = re.search("Portugal", txt)
print(x)

# %%
x = re.search("ai", txt)
print(x) #this will print an object

# %%
x = re.search(r"\bS\w+", txt)
print(x)
# span returns the start and end position of the first match occurrence.
print(x.span())

# %%
# look for upper case S
x = re.search(r"\bS\w+", txt)
# print the part of the string where there was a match
print(x.group())

# %% [markdown]
# ### Split
# The `split()` function returns a list where the string has been split on each match.  Notice this can also be accomplished with the string method `split()`.

# %%
# split on white space
x = re.split("\s", txt)
print(x)

# %%
txt = "The rain in Spain"
x = txt.split()
print(x)

# %% [markdown]
# ### Substitution
# The `sub()` function replaces the matches found with a string you indicate.  You can control how many replacements are done with the optional count parameter.

# %%
# replace spaces with the number nine as a string
x = re.sub("\s", "9", txt)
print(x)

# %%
x = re.sub("\s", "9", txt, 2)
print(x)

# %% [markdown]
# ### Example application: Bioinformatics
# The flexibility of regular expression is particularly useful in bioinformatics.  A codon is a DNA or RNA sequence of 3 nucleotides that encodes a particular amino acid or gives a stop signal.  For DNA, there are three stop codons: TAG, TAA, and TGA.  If we want to match any sequence of DNA terminated by a stop codon, we can use this syntax:
# `([ACTG])+(TAG|TAA|TGA)`.
# - `[ACTG]` indicates any of the nucleotide bases (A, C, T, G)
# - the parentheses group patterns
# - `+` modifies the previous group to match one or more times
# - `(TAG|TAA|TGA)` indicates followed by one of the stop codons (the | notation signifies or)
#
# Curly brackets allow flexibility in terms of how many repetitions we are searching for.  For example, `(AT){10,100}` matches an "AT" repeated 10 to 100 times.  `(AT){10,}` matches an "AT" repeated 10 or more times (no upper bound).
#
# The GATA protein is a transcription factor and is important for regulating transcription (the process where cells make an RNA copy of a piece of DNA which will later be used to make proteins). It binds to any short DNA sequence which matches the pattern GATA with either an A or a T before and either a G or an A after.  For example, in this sequence
# - `AAAAAAATGATAGAAAAAGATAAAAAA`
# there are two matches (find the substring GATA, and then check that before you see an A or a T and after you see a G or an A).
#
# Given a specific string, we can use regular expression to find out how many times this motif occurs.

# %%
seq = 'AAAAAAATGATAGAAAAAGATAAAAAA'

matches = re.findall('[AT]GATA[GA]',seq)
print(matches)
count_motifs = len(matches)
print(count_motifs)

# %% [markdown]
# ## Appetizers
# Now it's time for you to get some practice.

# %% [markdown]
# **Question 1:** We have seen now different syntaxes to flexibly control what we want to match or replace.  Google "regular expression in Python cheat sheet" and download one of your choosing. Or use [this one](https://canvas.humboldt.edu/courses/71553/files/5254145?wrap=1). Take a moment to read through it.
# Choose four different syntaxes on the cheat sheet and write a small example with a string of your choosing like "The rain in Spain" to test them.
# Specifically experiment with
# - `[]` vs `()`
# - `+` vs `*`
# - `{}`
# - character classes like `\d`, `\w`, etc.
#
# If you can't think of things to try, try going to Stack Overflow and find a question related to regular expression in Python. Read the answer and test it out with code. (If the first one you find doesn't make sense, look for another.)  Did you learn anything about syntax from the example you found? Explain the problem and solution to a peer.

# %%
any_string = ...
some_practice = ...
some_practice

# %%
any_string = ...
some_practice = ...
some_practice

# %%
any_string = ...
some_practice = ...
some_practice

# %%
any_string = ...
some_practice = ...
some_practice

# %% [markdown]
# **Question 2.1:** We will use the text file *emails.txt* for this exercise. If you are working from your local device, this file needs to be in the same directory as your Jupyter notebook. If you are using JupyterHub, this is already done for you.
#
# Here is a snippet of the file:<br />
# *From bkirschn@umich.edu Fri Dec 21 09:55:06 2007<br />
# Return-Path: <postmaster@collab.sakaiproject.org><br />
# Received: from murder (mail.umich.edu [141.211.14.25])<br />
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;<br />
# 	 Fri, 21 Dec 2007 09:55:06 -0500<br />
# X-Sieve: CMU Sieve 2.3<br />
# Received: from murder ([unix socket])<br />
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;<br />
# 	 Fri, 21 Dec 2007 09:55:06 -0500<br />
# Received: from dreamcatcher.mr.itd.umich.edu (dreamcatcher.mr.itd.umich.edu [141.211.14.43])<br />
# 	by panther.mail.umich.edu () with ESMTP id lBLEt6x8006098;<br />
# 	Fri, 21 Dec 2007 09:55:06 -0500<br />
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])<br />
# 	BY dreamcatcher.mr.itd.umich.edu ID 476BD3C4.BFDC1.28307 ; <br />
# 	21 Dec 2007 09:55:03 -0500<br />
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])<br />
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id A4CC6A7DD7;<br />
# 	Fri, 21 Dec 2007 14:51:39 +0000 (GMT)<br />
# Message-ID: <200712211454.lBLEs7d9009944@nakamura.uits.iupui.edu><br />
# Mime-Version: 1.0<br />
# Content-Transfer-Encoding: 7bit*<br />
#
#
# Create a list `from_lines` containing the lines in the .txt file which contain the word `"From"` Be sure that the lines that end up in your list do not include any trailing characters (like spaces or newlines).
#
# *HINTS:* You can iterate though `hand` (i.e. `for line in hand` is valid). `rstrip()` method removes any trailing characters (characters at the end a string) with space as the default character to remove.
#
# *NOTE:* Feel free to solve this with list comprehension if you prefer that.

# %%
hand = open('emails.txt')
from_lines = []
for ... in ...: 
    clean_line = ... # remove trailing characters
    if ...: # search for the word "From"
        ... # add the line to list
hand.close  
from_lines

# %%
grader.check("q2_1")

# %% [markdown]
# **Question 2.2:** The real power of regular expression comes from adding special characters to the search string to more precisely control which lines match the string.  For example, what if there were some lines in the file that contained the word "From" but were not specifically a line indicating who sent the email? How could we adjust our regular expression if we just want the lines that contain "From" and a sender.
#
# *HINTs:* What should the line start with? What symbol is always present in email addresses? How do we handle the fact that the number of characters in email addresses vary?  For example, Humboldt's Math Department email is math@humboldt.edu and the Biology Deparment's email is biosci@humboldt.edu.

# %%
hand = open('emails.txt')
from_lines2 = ...
hand.close  
from_lines2

# %%
grader.check("q2_2")

# %% [markdown]
# ### Extracting Data with Regular Expression
# The method `findall()` finds *all* the matches and returns them as a list of strings, with each string representing one match.
# If we would like to find all the email addresses, we can search `'\S+@\S+'`.  This works because
# - `\S` matches a single character other than white space.  Adding the + means one or more characters other than white space, so `\S+` matches as many nonwhite space characters as possible (greedy).
# - `@` looks for the sign in all email addresses
# - `\S+` again looks for non white space characters
#
# The terms greedy and lazy in regular expression mean
# - greedy (default): keep searching until the condition is not satisfied
# - lazy (indicated with a ? at the end of the quantifier): stop searching once the condition is satisfied

# %%
hand = open('emails.txt')
emails = [re.findall('\S+@\S+',line) for line in hand if re.search('\S+@\S+',line)]
hand.close  
emails

# %% [markdown]
# **Question 2.3:** We see some of the email addresses returned have characters we might not want.  For example,we might want to remove the `<` and `>` in this address: `<postmaster@collab.sakaiproject.org>`. Write a regex to extract cleaner email addresses.
#
# *HINT*: Email addresses have a single lowercase character, uppercase character, or digit followed by zero or more non whitespace characters follwed by an `@` sign followed by zero or more non whitespace characters, and they end with a letter.

# %%
hand = open('emails.txt')
emails2 = ...
hand.close  
emails2

# %%
grader.check("q2_3")

# %% [markdown]
# **Question 2.4:** Based on what you know about regular expressions, can you come up with a differnt expression that will accomplish the same goal as the previous cell? That is, can you create a list equivalent to `emails2` using a different regex?

# %%
hand = open('emails.txt')
emails3 = ...
hand.close  
emails3

# %%
grader.check("q2_4")

# %% [markdown]
# ## `re` vs string methods

# %% [markdown]
# **Question 3.1:** Let the following string be considered: `'X-DSPAM-Confidence: 0.8475'`. Use `find` and string slicing to extract the number and convert it to a float. *HINT:* Everything after the colon is the number.
#
# *NOTE:* You should not use regular expressions in your solution. The next question will ask you to do the same task with a regex.

# %%
phrase = 'X-DSPAM-Confidence: 0.8475'

col_pos = ...
number = ...
number

# %%
grader.check("q3_1")

# %% [markdown]
# **Question 3.2:** Consider the same string: `'X-DSPAM-Confidence: 0.8475'`. Complete the same task you did in question 3.1, but this time use a regular expression.

# %%
number_with_re = ...
number_with_re = ...
number_with_re

# %%
grader.check("q3_2")

# %% [markdown]
# **Question 4.1:** Using *emails.txt*, extract the hour of day that email messages were sent and put them into a list (e.g., `'09'` for 9am). Your final answer should be a list of strings. Reminder: the emails looked something like
#
# `From gsilver@umich.edu Wed Dec 19 09:35:37 2007`
#
# *HINT:* One way to do this is by splitting each line twice. What could we split by to isolate the hour?
#
# *NOTE:* You should not use regular expression in your solution. The next question will ask you to do the same task with a regex. As always, feel free to use comprehension if you prefer.

# %%
hand = open('emails.txt')
hour_of_day = ... 
for ... in ...: 
    clean_line = line.rstrip() # remove trailing characters
    if not clean_line.startswith('From '): 
        continue # do nothing if it is not a line we are interested in 
    x = ... # split once 
    y = ... # split again 
    ... # add hour to list 
hand.close()

hour_of_day

# %%
grader.check("q4_1")

# %% [markdown]
# **Question 4.2:** Using *emails.txt*, extract the hour of day that email messages were sent and put them into a list like you did in question 4.1. This time, use regular expression.
#
# *HINT:* Look for lines that start with `From` then have a space, potentially some number of characters followed by a space and two digits followed by a colon.  Extract the two digits. Your final answer should be a list of strings. Use list comprehension if you want.

# %%
hand = open('emails.txt')
hour_of_day_with_re = ...
...
    clean_line = ...
    x = ...
    ...
        ...
hand.close()
hour_of_day

# %%
grader.check("q4_2")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Question 4.3:** We see that there are numerous tasks that can be accomplished with either string methods or regular expressions. Describe at least one scenario in which regular expression would be our only (or at least a much easier) option. Be sure to include what the data would look like, and what the task would be.

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ### 5. Main Course
# In this problem you will read through and parse a file with text and numbers. You will extract all the numbers in the file and compute the sum of the numbers.
#
# The file contains text from a data science textbook introduction with random numbers inserted through the verbage.
#
# For example, the text might look like this:
#
# *Why should you learn to write programs? 7746 <br>
# 12 1929 8827<br>
# Writing programs (or programming) is a very creative<br>
# 7 and rewarding activity.  You can write programs for <br>
# many reasons, ranging from making your living to solving<br>
# 8837 a difficult data analysis problem to having fun to helping 128<br>
# someone else solve a problem.  This book assumes that <br>
# everyone needs to know how to program ...*<br>
#
#
# The data can be found at this link: http://py4e-data.dr-chuck.net/regex_sum_1742785.txt.

# %% [markdown]
# **Question 5.1:** Open the `regex_sum_1742785.txt` file. Make a list of lists, where each sublist contains the numbers (str type) that appear in the cooresponding line of the file.
#
# *NOTE:* Add an empty list the list when there are no numbers in a given line and consider groups of digits. i.e. For the example snippet above, `['7746']` would be the first element of the list.

# %%
file = open('regex_sum_1742785.txt')

numbers_in_line = ...
...
    ...
    
file.close()
numbers_in_line

# %%
grader.check("q5_1")

# %% [markdown]
# **Question 5.2:** Convert the strings from the previous question to integers.
#
# *NOTE:* By the end, you should have a list of ints. This new list should NOT contain elements corresponding to the empty lists from the previous question.

# %%
strings_to_ints = ...
...
    ...
        ...
            ...
strings_to_ints

# %%
grader.check("q5_2")

# %% [markdown]
# **Question 5.3:** Add up all the integers from problem 5.2.

# %%
sum_all_nums = ...
sum_all_nums

# %%
grader.check("q5_3")

# %% [markdown]
# **Question 5.4:** Create a list where each element is a string cooresponding to a line from the original `regex_sum_1742785.txt` file with all the numbers and trailing characters removed.

# %%
file = ...
cleaned_lines = ...
...
cleaned_lines

# %%
grader.check("q5_4")

# %% [markdown]
# ### 6. Dessert
# Huntington's Disease is a neurogenerative disorder and is linked to the anomalous expansion of the number of tribucleotide repeats in particular genes.  Human beings have 23 pairs of chromosomes in our cells and each of our parents contributes one chromosome to each pair. The gene that causes Huntington's Disease (HD) is found on chromosome 4.  Each of us gets one copy of the gene from our mother and one copy from our father.
#
# The gene responsible for HD contains a sequence with several CAG repeats (cytosine, adenine, guanine which are bases forming this specific codon). We all have these CAG repeats in the gene that codes for the huntingtin protein, but people with HD have a greater number than usual of CAG repeats in one of the genes they inherited.  (This protein is found in many of the body's tissues, with the highest levels of activity in the brain. Within cells, this protein may be involved in chemical signaling, transporting materials, binding to proteins and other structures, etc.)
#
# The actual number of repeats of a specific codon determines the risk of developing HD. More than 35 repeats virtually assures the disease.  In this task, we will use regular expression to find the number of repeats of the CAG codon in a specific mRNA sequence.

# %% [markdown]
# **Question 6:** Using the *HTTmRNA.txt* file ([source](https://www.ncbi.nlm.nih.gov/nuccore/NM_002111.8?report=fasta)), use regular expression to determine how many times either CAG is repeated. *HINT:* You should play around with the `htt_pattern` to figure this out. Then manually enter your answer in `num_repeats`. If you think of another way to solve this, just put your answer in `num_repeats`.

# %%
fhand = open('HTTmRNA.txt')
htt_mRNA = fhand.read()
htt_pattern = ...
match = ...
print(len(match))
num_repeats = ...
fhand.close()

# %%
grader.check("q6_1")

# %% [markdown]
# ### Submission
# Congratulations on finishing Lab 3! Gus is very proud of you. Run the cell below to download a zip and upload to Canvas.
#
# <img src="gus_spies_on_neighbors.JPG" alt="drawing" width="300"/>
#
# ### References
# - Python for Everybody: Exploring Data in Python 3 by Charles Severance.  https://www.py4e.com/book.php
# - Möncke‐Buchner, Elisabeth, et al. "Counting CAG repeats in the Huntington’s disease gene by restriction endonuclease Eco P15I cleavage." Nucleic Acids Research 30.16 (2002): e83-e83.
# - A Primer for Computational Biology by Shawn T. ONeil https://open.oregonstate.education/computationalbiology/chapter/bioinformatics-knick-knacks-and-regular-expressions/
# - Using Regular Expression in Genetics with Python by Stephen Fordham.  https://towardsdatascience.com/using-regular-expression-in-genetics-with-python-175e2b9395c2

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(pdf=False, run_tests=True)

# %%
# Initialize Otter
import otter
grader = otter.Notebook("lab03.ipynb")

# %% [markdown]
# # Lab 3: Regular Expression with Python

# %% [markdown]
# Welcome to Lab 3 of DATA 271!
#
# This document contains examples and small tasks ("appetizers") for you to make sure you understand the examples.  The culminating task ("main course") at the end of the document is more complex, and uses most of the topics you have will have worked through. You should rarely remain stuck for more than a few minutes on questions in labs, so feel free to ask for help. Collaborating on labs is more than okay -- it's encouraged! Explaining things is beneficial -- the best way to solidify your knowledge of a subject is to explain it. Please don't just share answers, though.
#
# For this lab and all future ones, please be sure to not re-assign variables throughout the notebook! For example, if you use `my_list` in your answer to one question, do not reassign it later on. Otherwise, you will fail tests that you passed previously!

# %% [markdown]
# ### In today's lab, we will
# - Learn basic syntax for regular expression in Python and be able to write simple regular expressions using common operations in pattern matching.
# - Understand the flexibility regular expression affords in searching and articulate at least one real world example where this is useful
# - Become familiar with Python's `re` module and some of its functions such as `findall()`, `search()`, and `sub()`.
# - Become more familiar with using online resources such as documentation, "cheat sheets" and Stack Exchange to independently learn more about a technical topic.

# %% [markdown]
# ## Overview
#
# Regular expression (shortened as regex or regexp) can be used for pattern matching in a text editor.  For example, when you use the "find and replace" feature in Microsoft Word, you are asking the computer to find specific strings which match a pattern and replace them with another string. We might desire a more flexible way to search and replace. For example, we might wish to locate and replace a word spelled two different ways in a text: serialise and serialize (British and American spelling). The regular expression `seriali[sz]e` matches both "serialise" and "serialize". Wildcard characters also achieve this, but are more limited in what they can pattern.
#
# Other examples where this flexibilty is useful might be searching for and extracting email addresses from a file.  We know there will be an at sign (@), but don't know what the constraints are in front of it in terms of word length or characters used. It is possible to read through texts and look for patterns using string methods like `split()` and `find()`. However, searching and extracting is so common that there is a powerful library for these tasks (`re`).
#
# The `re` module provides a set of powerful regular expression facilities, which allows you to quickly check whether a given string matches a given pattern (using the match function), or contains such a pattern (using the search function). A regular expression is a string pattern written in a compact (and quite cryptic) syntax.
#
# The module functions fall into three categories:
# - pattern matching
# - substitution
# - splitting
#
# The regex describes a pattern to locate in the text, and then we can use specific methods to accomplish tasks.  You can then ask questions such as “Does this string match the pattern?”, or “Is there a match for the pattern anywhere in this string?” You can also use regular expression to modify a string or to split it apart in various ways.
#
# The documentation provides more details: https://docs.python.org/3/library/re.html.

# %% [markdown]
# ### Pattern matching

# %%
import re # Imports the re module

#Check if the string starts with "The" and ends with "Spain":

txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)

if x:
  print("YES! We have a match!")
else:
  print("No match")
# Out:
# YES! We have a match!

# %%
#Check if the string starts with "The" and ends with "Spain":
txt = "The Running of the Bulls occurs in Pamplona, Spain"
x = re.search("^The.*Spain$", txt)

if x:
  print("YES! We have a match!")
else:
  print("No match")

# %%
#Check if the string starts with "The" and ends with "Spain":

txt = "The Louvre is in Paris, France"
x = re.search("^The.*Spain$", txt)

if x:
  print("YES! We have a match!")
else:
  print("No match")

# %% [markdown]
# ### Print Matches
# You can print any matches found with the following.

# %%
txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)
len(x) # how many matches are found

# %%
# returns an empty list if no matches are found
txt = "The rain in Spain"
x = re.findall("Portugal", txt)
print(x)

# %% [markdown]
# ### Search
# The `search()` function searches the string for a match and returns a match object if there is a match.  If there is more than one match, only the first occurence will be returned.  If there are no matches `None` is returned.  The match object returned has properties and methods which can provide more information about the search such as
# - `span()` which returns a tuple containing the start and end positions of the match
# - `group()` returns the part of the string where there was a match

# %%
txt = "The rain in Spain"
# search for first white space character \s
x = re.search("\s", txt)

print("The first white-space character is located in position:", x.start())

# %%
x = re.search("Portugal", txt)
print(x)

# %%
x = re.search("ai", txt)
print(x) #this will print an object

# %%
x = re.search(r"\bS\w+", txt)
print(x)
# span returns the start and end position of the first match occurrence.
print(x.span())

# %%
# look for upper case S
x = re.search(r"\bS\w+", txt)
# print the part of the string where there was a match
print(x.group())

# %% [markdown]
# ### Split
# The `split()` function returns a list where the string has been split on each match.  Notice this can also be accomplished with the string method `split()`.

# %%
# split on white space
x = re.split("\s", txt)
print(x)

# %%
txt = "The rain in Spain"
x = txt.split()
print(x)

# %% [markdown]
# ### Substitution
# The `sub()` function replaces the matches found with a string you indicate.  You can control how many replacements are done with the optional count parameter.

# %%
# replace spaces with the number nine as a string
x = re.sub("\s", "9", txt)
print(x)

# %%
x = re.sub("\s", "9", txt, 2)
print(x)

# %% [markdown]
# ### Example application: Bioinformatics
# The flexibility of regular expression is particularly useful in bioinformatics.  A codon is a DNA or RNA sequence of 3 nucleotides that encodes a particular amino acid or gives a stop signal.  For DNA, there are three stop codons: TAG, TAA, and TGA.  If we want to match any sequence of DNA terminated by a stop codon, we can use this syntax:
# `([ACTG])+(TAG|TAA|TGA)`.
# - `[ACTG]` indicates any of the nucleotide bases (A, C, T, G)
# - the parentheses group patterns
# - `+` modifies the previous group to match one or more times
# - `(TAG|TAA|TGA)` indicates followed by one of the stop codons (the | notation signifies or)
#
# Curly brackets allow flexibility in terms of how many repetitions we are searching for.  For example, `(AT){10,100}` matches an "AT" repeated 10 to 100 times.  `(AT){10,}` matches an "AT" repeated 10 or more times (no upper bound).
#
# The GATA protein is a transcription factor and is important for regulating transcription (the process where cells make an RNA copy of a piece of DNA which will later be used to make proteins). It binds to any short DNA sequence which matches the pattern GATA with either an A or a T before and either a G or an A after.  For example, in this sequence
# - `AAAAAAATGATAGAAAAAGATAAAAAA`
# there are two matches (find the substring GATA, and then check that before you see an A or a T and after you see a G or an A).
#
# Given a specific string, we can use regular expression to find out how many times this motif occurs.

# %%
seq = 'AAAAAAATGATAGAAAAAGATAAAAAA'

matches = re.findall('[AT]GATA[GA]',seq)
print(matches)
count_motifs = len(matches)
print(count_motifs)
# Out:
# ['TGATAG', 'AGATAA']
# 2

# %% [markdown]
# ## Appetizers
# Now it's time for you to get some practice.

# %% [markdown]
# **Question 1:** We have seen now different syntaxes to flexibly control what we want to match or replace.  Google "regular expression in Python cheat sheet" and download one of your choosing. Or use [this one](https://canvas.humboldt.edu/courses/71553/files/5254145?wrap=1). Take a moment to read through it.
# Choose four different syntaxes on the cheat sheet and write a small example with a string of your choosing like "The rain in Spain" to test them.
# Specifically experiment with
# - `[]` vs `()`
# - `+` vs `*`
# - `{}`
# - etc.
#
# Find one question on Stack Overflow related to regular expression in Python and read the answer and test it out with code. (If the first one you find doesn't make sense, look for another.)  Did you learn anything about syntax from the example you found? Be prepared to explain the problem and solution to a peer.

# %%
any_string = ...
some_practice = ...
some_practice

# %%
any_string = ...
some_practice = ...
some_practice

# %%
any_string = ...
some_practice = ...
some_practice

# %%
any_string = ...
some_practice = ...
some_practice

# %%
any_string = ...
some_practice = ...
some_practice

# %% [markdown]
# **Question 2:** We will use the text file *emails.txt* for this exercise. If you are working from your local device, this file needs to be in the same directory as your Jupyter notebook. If you are using JupyterHub, this is already done for you.
#
# Here is a snippet of the file:
#
# From bkirschn@umich.edu Fri Dec 21 09:55:06 2007
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.25])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Fri, 21 Dec 2007 09:55:06 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Fri, 21 Dec 2007 09:55:06 -0500
# Received: from dreamcatcher.mr.itd.umich.edu (dreamcatcher.mr.itd.umich.edu [141.211.14.43])
# 	by panther.mail.umich.edu () with ESMTP id lBLEt6x8006098;
# 	Fri, 21 Dec 2007 09:55:06 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY dreamcatcher.mr.itd.umich.edu ID 476BD3C4.BFDC1.28307 ;
# 	21 Dec 2007 09:55:03 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id A4CC6A7DD7;
# 	Fri, 21 Dec 2007 14:51:39 +0000 (GMT)
# Message-ID: <200712211454.lBLEs7d9009944@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
#
#
# Use the `search()` function to make a list of the lines in the .txt file which contain the word `"From"` Be sure that the lines that end up in your list do not include any trailing characters (like spaces or newlines).
#
# *HINT:* You can iterate though `hand`. `rstrip()` method removes any trailing characters (characters at the end a string) with space as the default character to remove.
#
# *NOTE* Feel free to solve this with list comprehension if you prefer that.

# %%
hand = open('emails.txt')
from_lines = []
for ... in ...: 
    clean_line = ... # remove trailing characters
    if ...: # search for the word "From"
        ... # add to list
hand.close  
from_lines

# %%
grader.check("q2")

# %% [markdown]
# The real power of regular expression comes from adding special characters to the search string to more precisely control which lines match the string.  For example, we can search for lines that start with `From` and have an `@` sign.
# - the `^` symbol indicates the start of the line
# - the `.+` means one or more characters.  Think of this as a wildcard expanding to match an unspecified number of characters.
# - the `@` looks for this sign
# - putting this together, we can search for `'^From.+@'`
#
# Notice that we don't have to specify how many characters are before the @.  This is good because email addresses vary.  For example, Humboldt's Math Department email is math@humboldt.edu and the Biology Deparment's email is biosci@humboldt.edu.  They have a different number of characters before the @ sign.  Therefore we need flexibility in the searching.
#
# Here is code to accomplish this task.

# %%
hand = open('emails.txt')
from_lines2 = [line.rstrip() for line in hand if re.search('^From.+@',line)]
hand.close  
from_lines2
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008',
#  'From: stephen.marquard@uct.ac.za',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008',
#  'From: louis@media.berkeley.edu',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008',
#  'From: rjlowe@iupui.edu',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008',
#  'From: zqian@umich.edu',
#  'From cwen@iupui.edu Wed Dec 19 09:45:21 2007',
#  'From: cwen@iupui.edu',
#  'From gsilver@umich.edu Wed Dec 19 09:35:37 2007',
#  'From: gsilver@umich.edu',
#  'From cwen@iupui.edu Wed Dec 19 08:47:43 2007',
#  'From: cwen@iupui.edu',
#  'From stuart.freeman@et.gatech.edu Wed Dec 19 08:41:55 2007',
#  'From: stuart.freeman@et.gatech.edu',
#  'From wagnermr@iupui.edu Wed Dec 19 08:39:56 2007',
#  'From: wagnermr@iupui.edu',
#  'From stuart.freeman@et.gatech.edu Wed Dec 19 08:35:04 2007',
#  'From: stuart.freeman@et.gatech.edu',
#  'From stephen.marquard@uct.ac.za Wed Dec 19 03:40:33 2007',
#  'From: stephen.marquard@uct.ac.za',
#  'From stephen.marquard@uct.ac.za Wed Dec 19 03:20:57 2007',
#  'From: stephen.marquard@uct.ac.za',
#  'From stephen.marquard@uct.ac.za Wed Dec 19 03:08:44 2007',
#  'From: stephen.marquard@uct.ac.za',
#  'From stephen.marquard@uct.ac.za Wed Dec 19 02:55:09 2007',
#  'From: stephen.marquard@uct.ac.za',
#  'From stephen.marquard@uct.ac.za Wed Dec 19 02:40:51 2007',
#  'From: stephen.marquard@uct.ac.za',
#  'From louis@media.berkeley.edu Tue Dec 18 20:32:23 2007',
#  'From: louis@media.berkeley.edu',
#  'From ian@caret.cam.ac.uk Wed Nov 21 12:20:03 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From antranig@caret.cam.ac.uk Wed Nov 21 12:16:38 2007',
#  'From: antranig@caret.cam.ac.uk',
#  'From ian@caret.cam.ac.uk Wed Nov 21 12:07:17 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From ian@caret.cam.ac.uk Wed Nov 21 11:59:21 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From ian@caret.cam.ac.uk Wed Nov 21 11:45:20 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From wagnermr@iupui.edu Tue Oct 30 08:15:12 2007',
#  'From: wagnermr@iupui.edu',
#  'From david.horwitz@uct.ac.za Tue Oct 30 07:48:17 2007',
#  'From: david.horwitz@uct.ac.za',
#  'From jleasia@umich.edu Tue Oct 30 07:18:55 2007',
#  'From: jleasia@umich.edu',
#  'From david.horwitz@uct.ac.za Tue Oct 30 05:40:21 2007',
#  'From: david.horwitz@uct.ac.za',
#  'From mmmay@indiana.edu Mon Oct 29 18:29:00 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 18:25:53 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 18:24:26 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 18:23:34 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 18:16:20 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 18:12:26 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 18:09:53 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 18:07:34 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 18:04:42 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 18:03:02 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:58:30 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:56:37 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:51:21 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:47:48 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:46:02 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:38:19 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:35:44 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:33:58 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:31:52 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:29:57 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:27:51 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:26:11 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:23:02 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:17:04 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:15:43 2007',
#  'From: mmmay@indiana.edu',
#  'From cwen@iupui.edu Mon Oct 29 17:12:03 2007',
#  'From: cwen@iupui.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:09:22 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:05:36 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 17:04:19 2007',
#  'From: mmmay@indiana.edu',
#  'From kimsooil@bu.edu Mon Oct 29 16:58:52 2007',
#  'From: kimsooil@bu.edu',
#  'From mmmay@indiana.edu Mon Oct 29 16:49:01 2007',
#  'From: mmmay@indiana.edu',
#  'From zqian@umich.edu Mon Oct 29 16:36:13 2007',
#  'From: zqian@umich.edu',
#  'From mmmay@indiana.edu Mon Oct 29 16:36:00 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 16:19:59 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 16:14:12 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 16:11:25 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 16:10:03 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 16:08:52 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 16:05:04 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 16:03:46 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 16:02:14 2007',
#  'From: mmmay@indiana.edu',
#  'From mmmay@indiana.edu Mon Oct 29 15:58:46 2007',
#  'From: mmmay@indiana.edu',
#  'From kimsooil@bu.edu Mon Oct 29 15:50:41 2007',
#  'From: kimsooil@bu.edu',
#  'From aaronz@vt.edu Mon Oct 29 15:33:35 2007',
#  'From: aaronz@vt.edu',
#  'From dlhaines@umich.edu Mon Oct 29 15:31:51 2007',
#  'From: dlhaines@umich.edu',
#  'From zqian@umich.edu Mon Oct 29 15:18:17 2007',
#  'From: zqian@umich.edu',
#  'From mmmay@indiana.edu Mon Oct 29 15:17:29 2007',
#  'From: mmmay@indiana.edu',
#  'From dlhaines@umich.edu Mon Oct 29 15:16:04 2007',
#  'From: dlhaines@umich.edu',
#  'From cwen@iupui.edu Mon Oct 29 14:47:17 2007',
#  'From: cwen@iupui.edu',
#  'From kimsooil@bu.edu Mon Oct 29 14:47:14 2007',
#  'From: kimsooil@bu.edu',
#  'From kimsooil@bu.edu Mon Oct 29 14:32:18 2007',
#  'From: kimsooil@bu.edu',
#  'From kimsooil@bu.edu Mon Oct 29 14:28:46 2007',
#  'From: kimsooil@bu.edu',
#  'From hu2@iupui.edu Mon Oct 29 14:09:42 2007',
#  'From: hu2@iupui.edu',
#  'From zqian@umich.edu Mon Oct 29 14:06:52 2007',
#  'From: zqian@umich.edu',
#  'From kimsooil@bu.edu Mon Oct 29 14:05:47 2007',
#  'From: kimsooil@bu.edu',
#  'From aaronz@vt.edu Mon Oct 29 14:03:43 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Mon Oct 29 14:03:25 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Mon Oct 29 14:03:11 2007',
#  'From: aaronz@vt.edu',
#  'From rjlowe@iupui.edu Mon Oct 29 13:31:21 2007',
#  'From: rjlowe@iupui.edu',
#  'From ajpoland@iupui.edu Mon Oct 29 13:27:36 2007',
#  'From: ajpoland@iupui.edu',
#  'From rjlowe@iupui.edu Mon Oct 29 13:26:51 2007',
#  'From: rjlowe@iupui.edu',
#  'From rjlowe@iupui.edu Mon Oct 29 13:25:04 2007',
#  'From: rjlowe@iupui.edu',
#  'From hu2@iupui.edu Mon Oct 29 13:16:37 2007',
#  'From: hu2@iupui.edu',
#  'From dlhaines@umich.edu Mon Oct 29 12:59:50 2007',
#  'From: dlhaines@umich.edu',
#  'From a.fish@lancaster.ac.uk Mon Oct 29 12:51:21 2007',
#  'From: a.fish@lancaster.ac.uk',
#  'From a.fish@lancaster.ac.uk Mon Oct 29 12:45:09 2007',
#  'From: a.fish@lancaster.ac.uk',
#  'From a.fish@lancaster.ac.uk Mon Oct 29 11:42:27 2007',
#  'From: a.fish@lancaster.ac.uk',
#  'From gsilver@umich.edu Mon Oct 29 11:42:17 2007',
#  'From: gsilver@umich.edu',
#  'From mbreuker@loi.nl Mon Oct 29 11:16:54 2007',
#  'From: mbreuker@loi.nl',
#  'From mbreuker@loi.nl Mon Oct 29 11:14:53 2007',
#  'From: mbreuker@loi.nl',
#  'From mbreuker@loi.nl Mon Oct 29 10:58:15 2007',
#  'From: mbreuker@loi.nl',
#  'From mbreuker@loi.nl Mon Oct 29 10:27:51 2007',
#  'From: mbreuker@loi.nl',
#  'From mbreuker@loi.nl Mon Oct 29 10:27:24 2007',
#  'From: mbreuker@loi.nl',
#  'From mbreuker@loi.nl Mon Oct 29 10:26:25 2007',
#  'From: mbreuker@loi.nl',
#  'From ajpoland@iupui.edu Mon Oct 29 10:22:43 2007',
#  'From: ajpoland@iupui.edu',
#  'From rjlowe@iupui.edu Mon Oct 29 10:22:13 2007',
#  'From: rjlowe@iupui.edu',
#  'From rjlowe@iupui.edu Mon Oct 29 10:20:04 2007',
#  'From: rjlowe@iupui.edu',
#  'From a.fish@lancaster.ac.uk Mon Oct 29 08:12:04 2007',
#  'From: a.fish@lancaster.ac.uk',
#  'From a.fish@lancaster.ac.uk Mon Oct 29 08:07:51 2007',
#  'From: a.fish@lancaster.ac.uk',
#  'From a.fish@lancaster.ac.uk Mon Oct 29 08:03:16 2007',
#  'From: a.fish@lancaster.ac.uk',
#  'From dlhaines@umich.edu Mon Oct 29 07:41:38 2007',
#  'From: dlhaines@umich.edu',
#  'From mbreuker@loi.nl Mon Oct 29 06:51:10 2007',
#  'From: mbreuker@loi.nl',
#  'From david.horwitz@uct.ac.za Mon Oct 29 06:46:00 2007',
#  'From: david.horwitz@uct.ac.za',
#  'From zach.thomas@txstate.edu Mon Oct 29 01:51:30 2007',
#  'From: zach.thomas@txstate.edu',
#  'From jimeng@umich.edu Sun Oct 28 20:48:23 2007',
#  'From: jimeng@umich.edu',
#  'From zqian@umich.edu Fri Oct 26 23:15:38 2007',
#  'From: zqian@umich.edu',
#  'From jzaremba@unicon.net Fri Oct 26 19:56:55 2007',
#  'From: jzaremba@unicon.net',
#  'From colin.clark@utoronto.ca Fri Oct 26 19:25:59 2007',
#  'From: colin.clark@utoronto.ca',
#  'From ray@media.berkeley.edu Fri Oct 26 19:02:09 2007',
#  'From: ray@media.berkeley.edu',
#  'From ray@media.berkeley.edu Fri Oct 26 17:10:03 2007',
#  'From: ray@media.berkeley.edu',
#  'From ray@media.berkeley.edu Fri Oct 26 16:49:42 2007',
#  'From: ray@media.berkeley.edu',
#  'From ray@media.berkeley.edu Fri Oct 26 16:25:40 2007',
#  'From: ray@media.berkeley.edu',
#  'From louis@media.berkeley.edu Fri Oct 26 15:37:43 2007',
#  'From: louis@media.berkeley.edu',
#  'From dlhaines@umich.edu Fri Oct 26 14:58:25 2007',
#  'From: dlhaines@umich.edu',
#  'From dlhaines@umich.edu Fri Oct 26 14:57:44 2007',
#  'From: dlhaines@umich.edu',
#  'From dlhaines@umich.edu Fri Oct 26 14:51:59 2007',
#  'From: dlhaines@umich.edu',
#  'From dlhaines@umich.edu Fri Oct 26 14:49:22 2007',
#  'From: dlhaines@umich.edu',
#  'From ajpoland@iupui.edu Fri Oct 26 14:11:40 2007',
#  'From: ajpoland@iupui.edu',
#  'From wagnermr@iupui.edu Fri Oct 26 14:08:50 2007',
#  'From: wagnermr@iupui.edu',
#  'From zqian@umich.edu Fri Oct 26 14:01:47 2007',
#  'From: zqian@umich.edu',
#  'From ktsao@stanford.edu Fri Oct 26 13:50:08 2007',
#  'From: ktsao@stanford.edu',
#  'From ray@media.berkeley.edu Fri Oct 26 13:26:30 2007',
#  'From: ray@media.berkeley.edu',
#  'From aaronz@vt.edu Fri Oct 26 13:03:38 2007',
#  'From: aaronz@vt.edu',
#  'From zqian@umich.edu Fri Oct 26 11:52:47 2007',
#  'From: zqian@umich.edu',
#  'From aaronz@vt.edu Fri Oct 26 11:42:08 2007',
#  'From: aaronz@vt.edu',
#  'From bahollad@indiana.edu Fri Oct 26 11:41:49 2007',
#  'From: bahollad@indiana.edu',
#  'From aaronz@vt.edu Fri Oct 26 11:40:15 2007',
#  'From: aaronz@vt.edu',
#  'From zqian@umich.edu Fri Oct 26 10:42:58 2007',
#  'From: zqian@umich.edu',
#  'From ray@media.berkeley.edu Fri Oct 26 10:42:23 2007',
#  'From: ray@media.berkeley.edu',
#  'From zqian@umich.edu Fri Oct 26 10:41:35 2007',
#  'From: zqian@umich.edu',
#  'From zqian@umich.edu Fri Oct 26 10:38:09 2007',
#  'From: zqian@umich.edu',
#  'From zqian@umich.edu Fri Oct 26 10:06:47 2007',
#  'From: zqian@umich.edu',
#  'From bahollad@indiana.edu Fri Oct 26 08:54:26 2007',
#  'From: bahollad@indiana.edu',
#  'From ray@media.berkeley.edu Fri Oct 26 08:19:32 2007',
#  'From: ray@media.berkeley.edu',
#  'From zqian@umich.edu Thu Oct 25 22:58:33 2007',
#  'From: zqian@umich.edu',
#  'From zqian@umich.edu Thu Oct 25 22:19:37 2007',
#  'From: zqian@umich.edu',
#  'From louis@media.berkeley.edu Thu Oct 25 21:28:17 2007',
#  'From: louis@media.berkeley.edu',
#  'From zqian@umich.edu Thu Oct 25 20:36:48 2007',
#  'From: zqian@umich.edu',
#  'From ray@media.berkeley.edu Thu Oct 25 20:13:54 2007',
#  'From: ray@media.berkeley.edu',
#  'From jzaremba@unicon.net Thu Oct 25 17:23:13 2007',
#  'From: jzaremba@unicon.net',
#  'From louis@media.berkeley.edu Thu Oct 25 17:19:10 2007',
#  'From: louis@media.berkeley.edu',
#  'From rjlowe@iupui.edu Thu Oct 25 16:37:54 2007',
#  'From: rjlowe@iupui.edu',
#  'From ajpoland@iupui.edu Thu Oct 25 15:47:33 2007',
#  'From: ajpoland@iupui.edu',
#  'From ray@media.berkeley.edu Thu Oct 25 15:36:10 2007',
#  'From: ray@media.berkeley.edu',
#  'From ajpoland@iupui.edu Thu Oct 25 15:31:35 2007',
#  'From: ajpoland@iupui.edu',
#  'From rjlowe@iupui.edu Thu Oct 25 15:31:02 2007',
#  'From: rjlowe@iupui.edu',
#  'From ray@media.berkeley.edu Thu Oct 25 14:31:42 2007',
#  'From: ray@media.berkeley.edu',
#  'From zqian@umich.edu Thu Oct 25 14:24:00 2007',
#  'From: zqian@umich.edu',
#  'From bkirschn@umich.edu Thu Oct 25 12:18:35 2007',
#  'From: bkirschn@umich.edu',
#  'From mbreuker@loi.nl Thu Oct 25 12:13:41 2007',
#  'From: mbreuker@loi.nl',
#  'From zqian@umich.edu Thu Oct 25 12:08:13 2007',
#  'From: zqian@umich.edu',
#  'From gsilver@umich.edu Thu Oct 25 11:59:58 2007',
#  'From: gsilver@umich.edu',
#  'From louis@media.berkeley.edu Thu Oct 25 11:31:49 2007',
#  'From: louis@media.berkeley.edu',
#  'From bkirschn@umich.edu Thu Oct 25 11:17:13 2007',
#  'From: bkirschn@umich.edu',
#  'From bkirschn@umich.edu Thu Oct 25 11:02:52 2007',
#  'From: bkirschn@umich.edu',
#  'From ajpoland@iupui.edu Thu Oct 25 09:20:41 2007',
#  'From: ajpoland@iupui.edu',
#  'From rjlowe@iupui.edu Thu Oct 25 09:20:00 2007',
#  'From: rjlowe@iupui.edu',
#  'From rjlowe@iupui.edu Thu Oct 25 09:16:13 2007',
#  'From: rjlowe@iupui.edu',
#  'From zach.thomas@txstate.edu Thu Oct 25 07:48:38 2007',
#  'From: zach.thomas@txstate.edu',
#  'From ian@caret.cam.ac.uk Thu Oct 25 07:20:36 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From ian@caret.cam.ac.uk Thu Oct 25 05:02:18 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From ray@media.berkeley.edu Wed Oct 24 18:09:53 2007',
#  'From: ray@media.berkeley.edu',
#  'From ktsao@stanford.edu Wed Oct 24 16:52:55 2007',
#  'From: ktsao@stanford.edu',
#  'From zqian@umich.edu Wed Oct 24 16:23:43 2007',
#  'From: zqian@umich.edu',
#  'From ian@caret.cam.ac.uk Wed Oct 24 15:57:55 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From chmaurer@iupui.edu Wed Oct 24 15:50:17 2007',
#  'From: chmaurer@iupui.edu',
#  'From ian@caret.cam.ac.uk Wed Oct 24 15:43:27 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From gjthomas@iupui.edu Wed Oct 24 15:18:05 2007',
#  'From: gjthomas@iupui.edu',
#  'From gjthomas@iupui.edu Wed Oct 24 15:17:35 2007',
#  'From: gjthomas@iupui.edu',
#  'From aaronz@vt.edu Wed Oct 24 12:09:08 2007',
#  'From: aaronz@vt.edu',
#  'From ian@caret.cam.ac.uk Wed Oct 24 11:52:31 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From aaronz@vt.edu Wed Oct 24 11:31:42 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Wed Oct 24 11:11:47 2007',
#  'From: aaronz@vt.edu',
#  'From zqian@umich.edu Wed Oct 24 09:58:46 2007',
#  'From: zqian@umich.edu',
#  'From aaronz@vt.edu Wed Oct 24 08:08:46 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Wed Oct 24 08:08:40 2007',
#  'From: aaronz@vt.edu',
#  'From mbreuker@loi.nl Wed Oct 24 07:13:09 2007',
#  'From: mbreuker@loi.nl',
#  'From ian@caret.cam.ac.uk Wed Oct 24 04:07:45 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From zqian@umich.edu Tue Oct 23 21:15:34 2007',
#  'From: zqian@umich.edu',
#  'From zqian@umich.edu Tue Oct 23 21:12:48 2007',
#  'From: zqian@umich.edu',
#  'From ian@caret.cam.ac.uk Tue Oct 23 19:54:11 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From ian@caret.cam.ac.uk Tue Oct 23 19:47:28 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From ian@caret.cam.ac.uk Tue Oct 23 19:46:21 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From ian@caret.cam.ac.uk Tue Oct 23 19:44:39 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From dlhaines@umich.edu Tue Oct 23 19:42:35 2007',
#  'From: dlhaines@umich.edu',
#  'From ian@caret.cam.ac.uk Tue Oct 23 18:31:43 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From ian@caret.cam.ac.uk Tue Oct 23 18:28:35 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From ian@caret.cam.ac.uk Tue Oct 23 17:36:42 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From zqian@umich.edu Tue Oct 23 17:21:59 2007',
#  'From: zqian@umich.edu',
#  'From ian@caret.cam.ac.uk Tue Oct 23 17:21:54 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From aaronz@vt.edu Tue Oct 23 14:00:37 2007',
#  'From: aaronz@vt.edu',
#  'From zqian@umich.edu Tue Oct 23 12:38:43 2007',
#  'From: zqian@umich.edu',
#  'From zqian@umich.edu Tue Oct 23 12:23:55 2007',
#  'From: zqian@umich.edu',
#  'From zqian@umich.edu Tue Oct 23 12:19:42 2007',
#  'From: zqian@umich.edu',
#  'From chmaurer@iupui.edu Tue Oct 23 11:37:04 2007',
#  'From: chmaurer@iupui.edu',
#  'From chmaurer@iupui.edu Tue Oct 23 11:19:14 2007',
#  'From: chmaurer@iupui.edu',
#  'From zqian@umich.edu Tue Oct 23 10:11:17 2007',
#  'From: zqian@umich.edu',
#  'From gjthomas@iupui.edu Tue Oct 23 09:23:04 2007',
#  'From: gjthomas@iupui.edu',
#  'From gsilver@umich.edu Tue Oct 23 09:15:07 2007',
#  'From: gsilver@umich.edu',
#  'From ian@caret.cam.ac.uk Tue Oct 23 09:12:54 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From ajpoland@iupui.edu Tue Oct 23 08:42:32 2007',
#  'From: ajpoland@iupui.edu',
#  'From aaronz@vt.edu Tue Oct 23 08:37:36 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Tue Oct 23 07:45:30 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Tue Oct 23 07:44:39 2007',
#  'From: aaronz@vt.edu',
#  'From zach.thomas@txstate.edu Mon Oct 22 19:57:34 2007',
#  'From: zach.thomas@txstate.edu',
#  'From ajpoland@iupui.edu Mon Oct 22 18:24:00 2007',
#  'From: ajpoland@iupui.edu',
#  'From zqian@umich.edu Mon Oct 22 16:41:38 2007',
#  'From: zqian@umich.edu',
#  'From zqian@umich.edu Mon Oct 22 15:48:14 2007',
#  'From: zqian@umich.edu',
#  'From zqian@umich.edu Mon Oct 22 15:23:49 2007',
#  'From: zqian@umich.edu',
#  'From gjthomas@iupui.edu Mon Oct 22 14:54:31 2007',
#  'From: gjthomas@iupui.edu',
#  'From rjlowe@iupui.edu Mon Oct 22 14:44:14 2007',
#  'From: rjlowe@iupui.edu',
#  'From rjlowe@iupui.edu Mon Oct 22 14:40:54 2007',
#  'From: rjlowe@iupui.edu',
#  'From dlhaines@umich.edu Mon Oct 22 14:18:25 2007',
#  'From: dlhaines@umich.edu',
#  'From rjlowe@iupui.edu Mon Oct 22 13:38:03 2007',
#  'From: rjlowe@iupui.edu',
#  'From rjlowe@iupui.edu Mon Oct 22 13:34:10 2007',
#  'From: rjlowe@iupui.edu',
#  'From aaronz@vt.edu Mon Oct 22 13:19:58 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Mon Oct 22 13:19:33 2007',
#  'From: aaronz@vt.edu',
#  'From cwen@iupui.edu Fri Oct 19 15:30:58 2007',
#  'From: cwen@iupui.edu',
#  'From ktsao@stanford.edu Fri Oct 19 13:58:01 2007',
#  'From: ktsao@stanford.edu',
#  'From aaronz@vt.edu Fri Oct 19 13:56:22 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Fri Oct 19 13:55:57 2007',
#  'From: aaronz@vt.edu',
#  'From gsilver@umich.edu Fri Oct 19 13:36:28 2007',
#  'From: gsilver@umich.edu',
#  'From gsilver@umich.edu Fri Oct 19 12:37:05 2007',
#  'From: gsilver@umich.edu',
#  'From zqian@umich.edu Fri Oct 19 11:34:47 2007',
#  'From: zqian@umich.edu',
#  'From jzaremba@unicon.net Fri Oct 19 11:15:27 2007',
#  'From: jzaremba@unicon.net',
#  'From aaronz@vt.edu Fri Oct 19 10:23:52 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Fri Oct 19 10:23:30 2007',
#  'From: aaronz@vt.edu',
#  'From dlhaines@umich.edu Fri Oct 19 10:16:11 2007',
#  'From: dlhaines@umich.edu',
#  'From dlhaines@umich.edu Fri Oct 19 10:14:17 2007',
#  'From: dlhaines@umich.edu',
#  'From dlhaines@umich.edu Fri Oct 19 10:08:50 2007',
#  'From: dlhaines@umich.edu',
#  'From ajpoland@iupui.edu Fri Oct 19 09:24:52 2007',
#  'From: ajpoland@iupui.edu',
#  'From rjlowe@iupui.edu Fri Oct 19 09:23:36 2007',
#  'From: rjlowe@iupui.edu',
#  'From rjlowe@iupui.edu Fri Oct 19 09:22:52 2007',
#  'From: rjlowe@iupui.edu',
#  'From rjlowe@iupui.edu Fri Oct 19 09:19:00 2007',
#  'From: rjlowe@iupui.edu',
#  'From dlhaines@umich.edu Fri Oct 19 09:17:36 2007',
#  'From: dlhaines@umich.edu',
#  'From aaronz@vt.edu Fri Oct 19 06:54:53 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Fri Oct 19 06:52:08 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Fri Oct 19 06:51:45 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Fri Oct 19 06:18:11 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Fri Oct 19 06:16:33 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Fri Oct 19 06:16:22 2007',
#  'From: aaronz@vt.edu',
#  'From ian@caret.cam.ac.uk Fri Oct 19 06:12:08 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From aaronz@vt.edu Fri Oct 19 06:01:00 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Fri Oct 19 06:00:45 2007',
#  'From: aaronz@vt.edu',
#  'From ktsao@stanford.edu Fri Oct 19 02:00:02 2007',
#  'From: ktsao@stanford.edu',
#  'From ian@caret.cam.ac.uk Thu Oct 18 18:43:47 2007',
#  'From: ian@caret.cam.ac.uk',
#  'From zqian@umich.edu Thu Oct 18 16:42:05 2007',
#  'From: zqian@umich.edu',
#  'From zqian@umich.edu Thu Oct 18 16:41:19 2007',
#  'From: zqian@umich.edu',
#  'From zqian@umich.edu Thu Oct 18 16:29:46 2007',
#  'From: zqian@umich.edu',
#  'From zqian@umich.edu Thu Oct 18 16:10:39 2007',
#  'From: zqian@umich.edu',
#  'From zqian@umich.edu Thu Oct 18 16:02:03 2007',
#  'From: zqian@umich.edu',
#  'From aaronz@vt.edu Thu Oct 18 13:30:28 2007',
#  'From: aaronz@vt.edu',
#  'From aaronz@vt.edu Thu Oct 18 13:14:54 2007',
#  'From: aaronz@vt.edu',
#  'From jzaremba@unicon.net Thu Oct 18 12:17:38 2007',
#  'From: jzaremba@unicon.net',
#  'From dlhaines@umich.edu Thu Oct 18 12:08:06 2007',
#  'From: dlhaines@umich.edu',
#  'From chmaurer@iupui.edu Thu Oct 18 11:51:45 2007',
#  'From: chmaurer@iupui.edu',
#  'From zach.thomas@txstate.edu Thu Oct 18 11:34:11 2007',
#  'From: zach.thomas@txstate.edu',
#  'From dlhaines@umich.edu Thu Oct 18 10:56:16 2007',
#  'From: dlhaines@umich.edu']

# %% [markdown]
# ### Extracting Data with Regular Expression
# The method `findall()` finds *all* the matches and returns them as a list of strings, with each string representing one match.
# If we would like to find all strings that look like email addresses, we can search `'\S+@\S+'`.  This works because
# - `\S` matches a single character other than white space.  Adding the + means one or more characters other than white space, so `\S+` matches as many nonwhite space characters as possible (greedy).
# - `@` looks for the sign in all email addresses
# - `\S+` again looks for non white space characters
#
# The terms greedy and lazy in regular expression mean
# - greedy (default): keep searching until the condition is not satisfied
# - lazy (indicated with a ? at the end of the quantifier): stop searching once the condition is satisfied

# %%
hand = open('emails.txt')
emails = [re.findall('\S+@\S+',line) for line in hand if re.search('\S+@\S+',line)]
hand.close  
emails
# Out:
# [['stephen.marquard@uct.ac.za'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['stephen.marquard@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['louis@media.berkeley.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200801042308.m04N8v6O008125@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['louis@media.berkeley.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['louis@media.berkeley.edu'],
#  ['louis@media.berkeley.edu'],
#  ['zqian@umich.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200801042109.m04L92hb007923@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['zqian@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['zqian@umich.edu'],
#  ['zqian@umich.edu'],
#  ['rjlowe@iupui.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200801042044.m04Kiem3007881@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['rjlowe@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['rjlowe@iupui.edu'],
#  ['rjlowe@iupui.edu'],
#  ['zqian@umich.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200801042001.m04K1cO0007738@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['zqian@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['zqian@umich.edu'],
#  ['zqian@umich.edu'],
#  ['zqian@umich.edu'],
#  ['cwen@iupui.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200712191444.lBJEiclh004385@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['cwen@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['cwen@iupui.edu'],
#  ['cwen@iupui.edu'],
#  ['gsilver@umich.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200712191434.lBJEYnqE004362@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['gsilver@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['gsilver@umich.edu'],
#  ['gsilver@umich.edu'],
#  ['cwen@iupui.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200712191346.lBJDklkl004248@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['cwen@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['cwen@iupui.edu'],
#  ['cwen@iupui.edu'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200712191341.lBJDfGpk004210@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['wagnermr@iupui.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200712191338.lBJDctBc004195@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['wagnermr@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['wagnermr@iupui.edu'],
#  ['wagnermr@iupui.edu'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200712191334.lBJDYBvh004174@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['--(stuart@mothra:pts/2)-------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/linktool)--'],
#  ['--(stuart@mothra:pts/2)-------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/linktool)--'],
#  ['--(stuart@mothra:pts/2)-------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/linktool)--'],
#  ['--(stuart@mothra:pts/2)-------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/linktool)--'],
#  ['--(stuart@mothra:pts/2)-------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/linktool)--'],
#  ['--(stuart@mothra:pts/2)-------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/linktool)--'],
#  ['stephen.marquard@uct.ac.za'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200712190839.lBJ8dpwK003423@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['stephen.marquard@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200712190819.lBJ8JufT003389@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['stephen.marquard@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200712190807.lBJ87uFQ003337@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['stephen.marquard@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200712190753.lBJ7rMdH003296@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['stephen.marquard@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200712190740.lBJ7e2sK003275@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['stephen.marquard@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['louis@media.berkeley.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200712190033.lBJ0Xdt5003060@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['louis@media.berkeley.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['louis@media.berkeley.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200711211713.lALHDggx005370@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['ian@caret.cam.ac.uk'],
#  ['source@collab.sakaiproject.org'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['antranig@caret.cam.ac.uk'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200711211710.lALHAYE8005358@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['antranig@caret.cam.ac.uk'],
#  ['source@collab.sakaiproject.org'],
#  ['antranig@caret.cam.ac.uk'],
#  ['antranig@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200711211701.lALH14Bj005343@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['ian@caret.cam.ac.uk'],
#  ['source@collab.sakaiproject.org'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200711211653.lALGr0MF005323@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['ian@caret.cam.ac.uk'],
#  ['source@collab.sakaiproject.org'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200711211639.lALGdIME005311@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['ian@caret.cam.ac.uk'],
#  ['source@collab.sakaiproject.org'],
#  ['ian@caret.cam.ac.uk'],
#  ['wagnermr@iupui.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710301212.l9UCC30h021770@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['wagnermr@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['wagnermr@iupui.edu'],
#  ['wagnermr@iupui.edu'],
#  ['david.horwitz@uct.ac.za'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710301144.l9UBitVU021705@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['david.horwitz@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['david.horwitz@uct.ac.za'],
#  ['david.horwitz@uct.ac.za'],
#  ['jleasia@umich.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710301115.l9UBFbta021685@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['jleasia@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['jleasia@umich.edu'],
#  ['jleasia@umich.edu'],
#  ['david.horwitz@uct.ac.za'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710300937.l9U9b2d0021604@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['david.horwitz@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['david.horwitz@uct.ac.za'],
#  ['david.horwitz@uct.ac.za'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292225.l9TMP5AG020736@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292222.l9TMMl7n020724@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292221.l9TML6Ex020712@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292220.l9TMK5HM020700@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292213.l9TMD5JL020666@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292209.l9TM9GMs020648@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['zach.thomas@txstate.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292206.l9TM6d78020633@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292204.l9TM4P7Z020621@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['gsilver@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292201.l9TM1YtZ020609@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292159.l9TLxf25020589@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['zqian@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292155.l9TLtHmX020577@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['zqian@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292153.l9TLrMBh020565@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['gsilver@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292148.l9TLm6Ir020550@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292144.l9TLiXfJ020527@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292142.l9TLglwe020509@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292134.l9TLYws6020487@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['dsobiera@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292132.l9TLWY78020475@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['a.fish@lancaster.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292130.l9TLUl4c020463@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['colin.clark@utoronto.ca'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292128.l9TLSbt5020451@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['louis@media.berkeley.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292126.l9TLQncT020439@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['louis@media.berkeley.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292124.l9TLOdUZ020427@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['louis@media.berkeley.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292123.l9TLN2PO020404@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['louis@media.berkeley.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292119.l9TLJlq6020381@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['dsobiera@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292113.l9TLDvq9020358@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['bahollad@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292112.l9TLCSdF020346@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['cwen@iupui.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292108.l9TL8urp020334@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['cwen@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['cwen@iupui.edu'],
#  ['cwen@iupui.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292106.l9TL63EK020322@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['bahollad@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292102.l9TL2JXc020310@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['bkirschn@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292101.l9TL13bJ020298@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['bkirschn@umich.edu'],
#  ['bkirschn@umich.edu'],
#  ['kimsooil@bu.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292055.l9TKterX020284@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['kimsooil@bu.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['kimsooil@bu.edu'],
#  ['kimsooil@bu.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292045.l9TKjOrQ020260@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ktsao@stanford.edu'],
#  ['zqian@umich.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292033.l9TKX3c7020234@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['zqian@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['zqian@umich.edu'],
#  ['zqian@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292032.l9TKWnU0020222@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ktsao@stanford.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292016.l9TKGidX020173@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['gsilver@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292010.l9TKAtaC020161@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['dsobiera@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292008.l9TK8DLk020149@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292006.l9TK6sUa020125@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292005.l9TK5fTo020112@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292001.l9TK1tFt020100@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710292000.l9TK0Y6g020085@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710291958.l9TJwvN1020072@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710291955.l9TJtNQm020050@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['kimsooil@bu.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710291944.l9TJiVQl019968@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['kimsooil@bu.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['kimsooil@bu.edu'],
#  ['kimsooil@bu.edu'],
#  ['aaronz@vt.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710291930.l9TJUL9h019953@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['aaronz@vt.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['aaronz@vt.edu'],
#  ['aaronz@vt.edu'],
#  ['dlhaines@umich.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710291927.l9TJRrmc019941@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['dlhaines@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['dlhaines@umich.edu'],
#  ['dlhaines@umich.edu'],
#  ['zqian@umich.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710291915.l9TJF7Sk019922@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['zqian@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['zqian@umich.edu'],
#  ['zqian@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710291914.l9TJE9lc019910@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['joshua.ryan@asu.edu'],
#  ['dlhaines@umich.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710291912.l9TJCj7S019877@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['dlhaines@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['dlhaines@umich.edu'],
#  ['dlhaines@umich.edu'],
#  ['cwen@iupui.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710291843.l9TIhOTq019804@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['cwen@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['cwen@iupui.edu'],
#  ['cwen@iupui.edu'],
#  ['kimsooil@bu.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710291843.l9TIhOQd019807@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['kimsooil@bu.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['kimsooil@bu.edu'],
#  ['kimsooil@bu.edu'],
#  ['kimsooil@bu.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710291829.l9TIT35m019762@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['kimsooil@bu.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['kimsooil@bu.edu'],
#  ['kimsooil@bu.edu'],
#  ['kimsooil@bu.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710291825.l9TIPV65019739@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['kimsooil@bu.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['kimsooil@bu.edu'],
#  ['kimsooil@bu.edu'],
#  ['hu2@iupui.edu'],
#  ['<postmaster@collab.sakaiproject.org>'],
#  ['<200710291806.l9TI6SbG019698@nakamura.uits.iupui.edu>'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['<source@collab.sakaiproject.org>;'],
#  ['apache@localhost)'],
#  ['source@collab.sakaiproject.org;'],
#  ['hu2@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['hu2@iupui.edu'],
#  ...]

# %% [markdown]
# We see some of the email addresses returned have characters we might not want.  For example,we might want to remove the `<` and `>` in this address: `<postmaster@collab.sakaiproject.org>`.  We can just keep the portion of the string that starts with a letter or a number.
# - square brackets are used to indicate a set of multiple acceptable characters we consider matching
# - `[a-zA-Z0-9]\S*@\S*[a-zA-Z]` tells us to look for substrings that
#     - start with a single lowercase character, uppercase character or digit (`[a-zA-Z0-9]`)
#     - followed by zero or more nonblank characters (`\S*`)
#     - has an `@` sign
#     - is followed by zero or more nonblank characters which are letters (`*[a-zA-Z]`)
#     - note that `*` means zero or more and `+` means one or more, applied to the single character immediately to the left

# %%
hand = open('emails.txt')
emails2 = [re.findall('[a-zA-Z0-9]\S*@\S*[a-zA-Z]',line) for line in hand if re.search('\S+@\S+',line)]
hand.close  
emails2
# Out:
# [['stephen.marquard@uct.ac.za'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200801051412.m05ECIaH010327@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['louis@media.berkeley.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200801042308.m04N8v6O008125@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['louis@media.berkeley.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['louis@media.berkeley.edu'],
#  ['louis@media.berkeley.edu'],
#  ['zqian@umich.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200801042109.m04L92hb007923@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['zqian@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['zqian@umich.edu'],
#  ['zqian@umich.edu'],
#  ['rjlowe@iupui.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200801042044.m04Kiem3007881@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['rjlowe@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['rjlowe@iupui.edu'],
#  ['rjlowe@iupui.edu'],
#  ['zqian@umich.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200801042001.m04K1cO0007738@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['zqian@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['zqian@umich.edu'],
#  ['zqian@umich.edu'],
#  ['zqian@umich.edu'],
#  ['cwen@iupui.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200712191444.lBJEiclh004385@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['cwen@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['cwen@iupui.edu'],
#  ['cwen@iupui.edu'],
#  ['gsilver@umich.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200712191434.lBJEYnqE004362@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['gsilver@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['gsilver@umich.edu'],
#  ['gsilver@umich.edu'],
#  ['cwen@iupui.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200712191346.lBJDklkl004248@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['cwen@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['cwen@iupui.edu'],
#  ['cwen@iupui.edu'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200712191341.lBJDfGpk004210@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['wagnermr@iupui.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200712191338.lBJDctBc004195@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['wagnermr@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['wagnermr@iupui.edu'],
#  ['wagnermr@iupui.edu'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200712191334.lBJDYBvh004174@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['stuart.freeman@et.gatech.edu'],
#  ['stuart@mothra:pts/2)-------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/linktool'],
#  ['stuart@mothra:pts/2)-------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/linktool'],
#  ['stuart@mothra:pts/2)-------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/linktool'],
#  ['stuart@mothra:pts/2)-------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/linktool'],
#  ['stuart@mothra:pts/2)-------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/linktool'],
#  ['stuart@mothra:pts/2)-------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/linktool'],
#  ['stephen.marquard@uct.ac.za'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200712190839.lBJ8dpwK003423@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200712190819.lBJ8JufT003389@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200712190807.lBJ87uFQ003337@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200712190753.lBJ7rMdH003296@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200712190740.lBJ7e2sK003275@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['stephen.marquard@uct.ac.za'],
#  ['stephen.marquard@uct.ac.za'],
#  ['louis@media.berkeley.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200712190033.lBJ0Xdt5003060@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['louis@media.berkeley.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['louis@media.berkeley.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200711211713.lALHDggx005370@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['ian@caret.cam.ac.uk'],
#  ['source@collab.sakaiproject.org'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['antranig@caret.cam.ac.uk'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200711211710.lALHAYE8005358@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['antranig@caret.cam.ac.uk'],
#  ['source@collab.sakaiproject.org'],
#  ['antranig@caret.cam.ac.uk'],
#  ['antranig@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200711211701.lALH14Bj005343@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['ian@caret.cam.ac.uk'],
#  ['source@collab.sakaiproject.org'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200711211653.lALGr0MF005323@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['ian@caret.cam.ac.uk'],
#  ['source@collab.sakaiproject.org'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200711211639.lALGdIME005311@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['ian@caret.cam.ac.uk'],
#  ['source@collab.sakaiproject.org'],
#  ['ian@caret.cam.ac.uk'],
#  ['wagnermr@iupui.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710301212.l9UCC30h021770@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['wagnermr@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['wagnermr@iupui.edu'],
#  ['wagnermr@iupui.edu'],
#  ['david.horwitz@uct.ac.za'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710301144.l9UBitVU021705@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['david.horwitz@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['david.horwitz@uct.ac.za'],
#  ['david.horwitz@uct.ac.za'],
#  ['jleasia@umich.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710301115.l9UBFbta021685@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['jleasia@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['jleasia@umich.edu'],
#  ['jleasia@umich.edu'],
#  ['david.horwitz@uct.ac.za'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710300937.l9U9b2d0021604@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['david.horwitz@uct.ac.za'],
#  ['source@collab.sakaiproject.org'],
#  ['david.horwitz@uct.ac.za'],
#  ['david.horwitz@uct.ac.za'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292225.l9TMP5AG020736@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292222.l9TMMl7n020724@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292221.l9TML6Ex020712@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292220.l9TMK5HM020700@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292213.l9TMD5JL020666@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292209.l9TM9GMs020648@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['zach.thomas@txstate.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292206.l9TM6d78020633@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292204.l9TM4P7Z020621@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['gsilver@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292201.l9TM1YtZ020609@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292159.l9TLxf25020589@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['zqian@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292155.l9TLtHmX020577@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['zqian@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292153.l9TLrMBh020565@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['gsilver@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292148.l9TLm6Ir020550@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292144.l9TLiXfJ020527@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292142.l9TLglwe020509@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292134.l9TLYws6020487@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['dsobiera@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292132.l9TLWY78020475@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['a.fish@lancaster.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292130.l9TLUl4c020463@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['colin.clark@utoronto.ca'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292128.l9TLSbt5020451@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['louis@media.berkeley.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292126.l9TLQncT020439@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['louis@media.berkeley.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292124.l9TLOdUZ020427@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['louis@media.berkeley.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292123.l9TLN2PO020404@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['louis@media.berkeley.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292119.l9TLJlq6020381@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['dsobiera@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292113.l9TLDvq9020358@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['bahollad@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292112.l9TLCSdF020346@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['cwen@iupui.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292108.l9TL8urp020334@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['cwen@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['cwen@iupui.edu'],
#  ['cwen@iupui.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292106.l9TL63EK020322@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['bahollad@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292102.l9TL2JXc020310@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['bkirschn@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292101.l9TL13bJ020298@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['bkirschn@umich.edu'],
#  ['bkirschn@umich.edu'],
#  ['kimsooil@bu.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292055.l9TKterX020284@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['kimsooil@bu.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['kimsooil@bu.edu'],
#  ['kimsooil@bu.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292045.l9TKjOrQ020260@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ktsao@stanford.edu'],
#  ['zqian@umich.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292033.l9TKX3c7020234@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['zqian@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['zqian@umich.edu'],
#  ['zqian@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292032.l9TKWnU0020222@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ktsao@stanford.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292016.l9TKGidX020173@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['gsilver@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292010.l9TKAtaC020161@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['dsobiera@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292008.l9TK8DLk020149@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292006.l9TK6sUa020125@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292005.l9TK5fTo020112@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292001.l9TK1tFt020100@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710292000.l9TK0Y6g020085@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710291958.l9TJwvN1020072@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710291955.l9TJtNQm020050@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['ian@caret.cam.ac.uk'],
#  ['kimsooil@bu.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710291944.l9TJiVQl019968@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['kimsooil@bu.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['kimsooil@bu.edu'],
#  ['kimsooil@bu.edu'],
#  ['aaronz@vt.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710291930.l9TJUL9h019953@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['aaronz@vt.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['aaronz@vt.edu'],
#  ['aaronz@vt.edu'],
#  ['dlhaines@umich.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710291927.l9TJRrmc019941@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['dlhaines@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['dlhaines@umich.edu'],
#  ['dlhaines@umich.edu'],
#  ['zqian@umich.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710291915.l9TJF7Sk019922@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['zqian@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['zqian@umich.edu'],
#  ['zqian@umich.edu'],
#  ['mmmay@indiana.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710291914.l9TJE9lc019910@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['mmmay@indiana.edu'],
#  ['mmmay@indiana.edu'],
#  ['joshua.ryan@asu.edu'],
#  ['dlhaines@umich.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710291912.l9TJCj7S019877@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['dlhaines@umich.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['dlhaines@umich.edu'],
#  ['dlhaines@umich.edu'],
#  ['cwen@iupui.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710291843.l9TIhOTq019804@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['cwen@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['cwen@iupui.edu'],
#  ['cwen@iupui.edu'],
#  ['kimsooil@bu.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710291843.l9TIhOQd019807@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['kimsooil@bu.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['kimsooil@bu.edu'],
#  ['kimsooil@bu.edu'],
#  ['kimsooil@bu.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710291829.l9TIT35m019762@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['kimsooil@bu.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['kimsooil@bu.edu'],
#  ['kimsooil@bu.edu'],
#  ['kimsooil@bu.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710291825.l9TIPV65019739@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['kimsooil@bu.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['kimsooil@bu.edu'],
#  ['kimsooil@bu.edu'],
#  ['hu2@iupui.edu'],
#  ['postmaster@collab.sakaiproject.org'],
#  ['200710291806.l9TI6SbG019698@nakamura.uits.iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['source@collab.sakaiproject.org'],
#  ['apache@localhost'],
#  ['source@collab.sakaiproject.org'],
#  ['hu2@iupui.edu'],
#  ['source@collab.sakaiproject.org'],
#  ['hu2@iupui.edu'],
#  ...]

# %% [markdown]
# **Question 3.1:** Let the following string be considered: `'X-DSPAM-Confidence: 0.8475'`. Use `find` and string slicing to extract the number and convert it to a float. *HINT:* Everything after the colon is the number.
#
# *NOTE:* You should not use regular expression in your solution. The next question will ask you to do the same task with a regex.

# %%
phrase = 'X-DSPAM-Confidence: 0.8475'

col_pos = ...
number = ...
number

# %%
grader.check("q3_1")

# %% [markdown]
# **Question 3.2:** Consider the same string: `'X-DSPAM-Confidence: 0.8475'`. Complete the same task you did in question 3.1, but this time use regular expression.

# %%
number_with_re = ...
number_with_re = ...
number_with_re

# %%
grader.check("q3_2")

# %% [markdown]
# **Question 4.1:** Using *emails.txt*, extract the hour of day that email messages were sent and put them into a list. Reminder: the emails looked something like
#
# `From gsilver@umich.edu Wed Dec 19 09:35:37 2007`
#
# Do this with two calls to split (splitting on the colon and then on spaces is one way to extract the hour (e.g., 09 for 9 am)). *NOTE:* You should not use regular expression in your solution. The next question will ask you to do the same task with a regex.

# %%
hand = open('emails.txt')
hour_of_day = ... 
for ... in ...: 
    clean_line = line.rstrip() # remove trailing characters
    if not clean_line.startswith('From '): 
        continue # do nothing if it is not a line we are interested in 
    x = ... # split on colon 
    y = ... # split on space 
    ... # add hour to list 
hand.close()

hour_of_day

# %%
grader.check("q4_1")

# %% [markdown]
# **Question 4.2:** Using *emails.txt*, extract the hour of day that email messages were sent and put them into a list like you did in question 4.1. This time, use regular expression.
#
# *HINT:* Look for lines that start with `From` then have a space, potentially some number of characters followed by a space and two digits followed by a colon.  Extract the two digits. Your final answer should be a list of strings (not a list of lists).

# %%
hand = open('emails.txt')
hour_of_day_with_re = []
...
    clean_line = ...
    x = ...
    ...
        ...
hand.close()
hour_of_day

# %%
grader.check("q4_2")

# %% [markdown]
# ### 5. Main Course
# In this problem you will read through and parse a file with text and numbers. You will extract all the numbers in the file and compute the sum of the numbers.
#
#
# The file contains text from a data science textbook introduction with random numbers inserted through the verbage.
#
# For example, the text might look like this:
#
# *Why should you learn to write programs? 7746
# 12 1929 8827
# Writing programs (or programming) is a very creative
# 7 and rewarding activity.  You can write programs for
# many reasons, ranging from making your living to solving
# 8837 a difficult data analysis problem to having fun to helping 128
# someone else solve a problem.  This book assumes that
# everyone needs to know how to program ...*
#
#
# The data can be found at this link: http://py4e-data.dr-chuck.net/regex_sum_1742785.txt.

# %% [markdown]
# **Question 5.1:** Download the file from the link above and read the file. Look for collections of 1 or more numbers. Make a list of lists containing the numbers in each line of the file.
#
# *NOTE:* You may add to the list even if there are no matches.

# %%
file = open('regex_sum_1742785.txt')

numbers_in_line = ...
...
    ...
    
file.close()
numbers_in_line

# %%
grader.check("q5_1")

# %% [markdown]
# **Question 5.2:** Convert the strings from the previous question to integers.
#
# *NOTE:* By the end, you should have a list of ints. This new list should NOT contain elements corresponding to the empty lists from the previous question.

# %%
strings_to_ints = ...
...
    ...
        ...
            ...
strings_to_ints

# %%
grader.check("q5_2")

# %% [markdown]
# **Question 5.3:** Add up all the integers from problem 5.2.

# %%
sum_all_nums = ...
sum_all_nums

# %%
grader.check("q5_3")

# %% [markdown]
# ### 6. Dessert
# Huntington's Disease is a neurogenerative disorder and is linked to the anomalous expansion of the number of tribucleotide repeats in particular genes.  Human beings have 23 pairs of chromosomes in our cells and each of our parents contributes one chromosome to each pair. The gene that causes Huntington's Disease (HD) is found on chromosome 4.  Each of us gets one copy of the gene from our mother and one copy from our father.
#
# The gene responsible for HD contains a sequence with several CAG repeats (cytosine, adenine, guanine which are bases forming this specific codon). We all have these CAG repeats in the gene that codes for the huntingtin protein, but people with HD have a greater number than usual of CAG repeats in one of the genes they inherited.  (This protein is found in many of the body's tissues, with the highest levels of activity in the brain. Within cells, this protein may be involved in chemical signaling, transporting materials, binding to proteins and other structures, etc.)
#
# The actual number of repeats of a specific codon determines the risk of developing HD. More than 35 repeats virtually assures the disease.  In this task, we will use regular expression to find the number of repeats of the CAG codon in a specific mRNA sequence.

# %% [markdown]
# **Question 6:** Using the *HTTmRNA.txt* file ([source](https://www.ncbi.nlm.nih.gov/nuccore/NM_002111.8?report=fasta)), use regular expression to determine how many times either CAG is repeated. *HINT:* You may have to play around with the pattern to figure this out.

# %%
fhand = open('HTTmRNA.txt')
htt_mRNA = ...
htt_pattern = ...
match = ...
print(len(match))
num_repeats = ...
fhand.close()

# %%
grader.check("q6_1")

# %% [markdown]
# ### You're done!
# Congratulations on finishing Lab 3! Gus is very proud of you. Run the cell below to download a zip and upload to Canvas.
#
# <img src="gus_spies_on_neighbors.JPG" alt="drawing" width="300"/>
#
# ### References
# - Python for Everybody: Exploring Data in Python 3 by Charles Severance.  https://www.py4e.com/book.php
# - Möncke‐Buchner, Elisabeth, et al. "Counting CAG repeats in the Huntington’s disease gene by restriction endonuclease Eco P15I cleavage." Nucleic Acids Research 30.16 (2002): e83-e83.
# - A Primer for Computational Biology by Shawn T. ONeil https://open.oregonstate.education/computationalbiology/chapter/bioinformatics-knick-knacks-and-regular-expressions/
# - Using Regular Expression in Genetics with Python by Stephen Fordham.  https://towardsdatascience.com/using-regular-expression-in-genetics-with-python-175e2b9395c2

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(pdf=False, run_tests=True)
